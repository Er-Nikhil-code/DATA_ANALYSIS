# %%
import pandas as pd
import numpy as np

# %%
# Reading and displaying a .csv file 
iris_df = pd.read_csv("iris_dirty.csv", index_col=[0])
iris_df.head(5)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  Setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           NaN          3.6           1.4          0.2  setosa

# %%
# Displaying all the columns of dataset
iris_df.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
# Displaying information about the headers and the data-types
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  142 non-null    float64
#  1   Sepal.Width   139 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
# Converting all Speicies values to lower case
iris_df['Species'] = iris_df['Species'].str.lower()

# %%
# Displaying count of unique values in Species
iris_df['Species'].value_counts()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# Getting sum of all the null values column-wise
iris_df.isna().sum()
# Out:
# Sepal.Length     8
# Sepal.Width     11
# Petal.Length     0
# Petal.Width      0
# Species          0
# dtype: int64

# %% [markdown]
# So, there are NULL values present in the Length and Width columns.
# We can either remove it or fill it with some relevant values like some constant or mean.
# As the dataset is small and dropping the rows with null values will affect our result.
# So, we are filling the NULL values with the mean.

# %%
# Filling values with the mean of corresponding column
iris_df['Sepal.Length'] = iris_df['Sepal.Length'].fillna(value=iris_df['Sepal.Length'].mean())
iris_df['Sepal.Width'] = iris_df['Sepal.Width'].fillna(value = iris_df['Sepal.Width'].mean())

# %%
# Column-wise sum of NULL values after replacing NULL values with mean
iris_df.isna().sum()
# Out:
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
iris_df.rename(columns = {'' : 'S.No'}, inplace=True)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Species Petal Length and Width")
plt.ylabel('Size', color='red')
plt.scatter(x=iris_df["Species"], y=iris_df["Petal.Length"], color="green")
plt.scatter(x=iris_df['Species'],y=iris_df['Petal.Width'], color = 'red')

# %%
plt.title("Species Sepal Length and Width")
plt.ylabel('Size', color='red')
plt.scatter(x=iris_df["Species"], y=iris_df["Sepal.Length"], color="blue")
plt.scatter(x=iris_df['Species'],y=iris_df['Sepal.Width'], color = 'orange')

# %%
plt.title(" Petal Length and Width ", color = 'red')
plt.ylabel("Size", color="red")
plt.xlabel("Count", color="red")
plt.plot(iris_df["Petal.Length"], "ro")
plt.plot(iris_df["Petal.Width"], "b*")
plt.legend(["Petal Length", "Petal Width"])

# %%
plt.title(" Sepal Length and Width ", color = 'red')
plt.ylabel("Size", color="red")
plt.xlabel("Count", color="red")
plt.plot(iris_df['Sepal.Length'], 'ro')
plt.plot(iris_df['Sepal.Width'],'b*')
plt.legend(['Sepal Length', 'Sepal Width'])
